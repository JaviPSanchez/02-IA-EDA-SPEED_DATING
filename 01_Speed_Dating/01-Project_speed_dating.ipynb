# %% [markdown]
# # Speed Dating

# %% [markdown]
# ## IMPORT LIBRARIES

# %%
#Data manipulation
import pandas as pd
import numpy as np

#Statitistics
import seaborn as sns

#Distributions
import matplotlib.pyplot as plt

# Interactive Graphs
import plotly.io as pio
pio.renderers.default = "jupyterlab"
import plotly.express as px

# %% [markdown]
# ## DATA MANIPULATION

# %% [markdown]
# ### READ FILES

# %%
df = pd.read_csv('Speed Dating Data.csv',  encoding= 'ISO-8859-1')

# %% [markdown]
# ### VISUALIZE DATASET

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %% [markdown]
# ### EXPLORING DATASET

# %%
display(f"Number of rows / Number of columns: {df.shape[0]} / {df.shape[1]}")
pd.set_option('display.max_rows', None)
# display([col for col in df.columns])
summary_table = pd.DataFrame({
    'is_null_value': df.isnull().any(),
    'sum_null_value': df.isnull().sum(),
    'proporcion_null_value': (df.isnull().sum()/df.shape[0])*100,
    'count_values': df.count(),
    # 'unique': {print(f'{len(df.groupby(col).Name.nunique())}') for col in df},
    'type': df.dtypes,
    'mean': df.mean(),
    'max': df.max(),
    'min': df.min(),
})
# display(summary_table)
# Out:
# 'Number of rows / Number of columns: 8378 / 195'

# %% [markdown]
# ### CUSTOM DATASET

# %%
custom_df = {
    
}
sd = pd.DataFrame(custom_df)

# %%
gender = df.gender
age = df.age_o
display(gender.unique())
display(age.unique())
display(age.shape)
# Out:
# array([0, 1], dtype=int64)
# array([27., 22., 23., 24., 25., 30., 28., 21., 26., 29., nan, 39., 32.,
#        34., 35., 18., 20., 19., 37., 33., 36., 31., 42., 38., 55.])
# (8378,)

# %%
df.gender.value_counts()
# Out:
# 1    4194
# 0    4184
# Name: gender, dtype: int64

# %%
sns.countplot(df.gender)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
df_genre_vs_age = df[['gender', 'age_o']]
df_genre_vs_age.head()
# Out:
#    gender  age_o
# 0       0   27.0
# 1       0   22.0
# 2       0   22.0
# 3       0   23.0
# 4       0   24.0

# %%
type(gender)
# Out:
# pandas.core.series.Series

# %%
# fig = px.histogram(df, x = age)
# fig.show()
display(age.isnull().sum())
display(gender.isnull().sum())
# Out:
# 104
# 0

# %%
age_clean = age.dropna()
print(age_clean.shape)
# Out:
# (8274,)

# %%
fig = px.histogram(df, x = age_clean)
fig.show()

# %%
mask_female = df[df.gender == 0]
display(mask_female.shape)
mask_male = df[df.gender != 0]
display(mask_male.shape)
# Out:
# (4184, 195)
# (4194, 195)
